# %% [markdown]
# ## question 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def generate_population(size, x1_bounds, x2_bounds,x3_bounds):
    population = []

    for _ in range(size):
        individual = {
            "x1": np.random.uniform(*x1_bounds),
            "x2": np.random.uniform(*x2_bounds),
            "x3": np.random.uniform(*x3_bounds)           
        }
        population.append(individual)

    return population

# %%
def objective_fn(individual):
    x1= individual['x1']
    x2= individual['x2']
    x3= individual['x3']    
    return math.sqrt(x1)+math.sqrt(x2)+math.sqrt(x3)

# %%
def choose_individual(population, minimize=False):
    costs = np.array(list(map(objective_fn, population)))

    min_cost = np.min(costs)
    if min_cost < 0:
        costs += -min_cost
    
    if minimize:
        costs = costs.max() - costs
    
    costs_sum = np.sum(costs)
    return np.random.choice(population, 1, p=[c/costs_sum for c in costs])[0]

def cross_over(a, b,c):
    return {
        "x1": np.mean([a['x1'], b['x1'],c['x1']]),
        "x2": np.mean([a['x2'], b['x2'],c['x2']]),
        "x3": np.mean([a['x3'], b['x3'],c['x3']]),
    }

def mutate(individual, x_bounds, y_bounds):
    return {
        "x": np.clip(individual["x"] + np.random.uniform(-0.05, 0.05), x_bounds[0], x_bounds[1]),
        "y": np.clip(individual["y"] + np.random.uniform(-0.05, 0.05), y_bounds[0], y_bounds[1])
    }

def gen_next_pop(population, x_bounds, y_bounds):
    gen = []

    for _ in range(len(population)):
        a = choose_individual(population, minimize=True)
        b = choose_individual(population, minimize=True)

        individual = cross_over(a, b)
        individual = mutate(individual, x_bounds, y_bounds)
        gen.append(individual)

    return gen

def plot(x_bounds, y_bounds, mins, figsize=(15, 20)):
    fig = plt.figure(figsize=figsize)
    ax = fig.gca(projection="3d")

    x = np.linspace(*x_bounds, 100)
    y = np.linspace(*y_bounds, 100)
    x, y = np.meshgrid(x, y)
    z = x**2 + y**2

    x1 = np.array([data['x'] for data in mins])
    y1 = np.array([data['y'] for data in mins])
    z1 = x1**2 + y1**2

    ax.plot_surface(x, y, z, alpha=0.5, cmap="viridis")
    ax.scatter3D(x1, y1, z1, color="red")

# %%
x_bounds = [-4, 4]
y_bounds = [-4, 4]
gens = 100
population = generate_population(30, x_bounds, y_bounds)
mins = []

for i in range(gens):
    print(f"🧬 generation {i}")

    population = gen_next_pop(population, x_bounds, y_bounds)

    costs = np.array([objective_fn(individual) for individual in population])
    best_idx = np.argmin(costs)
    mins.append(population[best_idx])
    
    for individual in population:
        print(individual, objective_fn(individual))

print(f"\nbest: {population[best_idx]}: {costs[best_idx]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c5cf1168bcf7> in <module>
#       2 y_bounds = [-4, 4]
#       3 gens = 100
# ----> 4 population = generate_population(30, x_bounds, y_bounds)
#       5 mins = []
#       6
#
# TypeError: generate_population() missing 1 required positional argument: 'x3_bounds'

# %%
import numpy as np

# Particle Swarm Optimization
def PSO(problem, MaxIter = 100, PopSize = 100, c1 = 1.4962, c2 = 1.4962, w = 0.7298, wdamp = 1.0):

    # Empty Particle Template
    empty_particle = {
        'position': None, 
        'velocity': None, 
        'cost': None, 
        'best_position': None, 
        'best_cost': None, 
    }

    # Extract Problem Info
    CostFunction = problem['CostFunction']
    VarMin = problem['VarMin']
    VarMax = problem['VarMax']
    nVar = problem['nVar']

    # Initialize Global Best
    gbest = {'position': None, 'cost': np.inf}

    # Create Initial Population
    pop = []
    for i in range(0, PopSize):
        pop.append(empty_particle.copy())
        pop[i]['position'] = np.random.uniform(VarMin, VarMax, nVar)
        pop[i]['velocity'] = np.zeros(nVar)
        pop[i]['cost'] = CostFunction(pop[i]['position'])
        pop[i]['best_position'] = pop[i]['position'].copy()
        pop[i]['best_cost'] = pop[i]['cost']
        
        if pop[i]['best_cost'] < gbest['cost']:
            gbest['position'] = pop[i]['best_position'].copy()
            gbest['cost'] = pop[i]['best_cost']
    
    # PSO Loop
    for it in range(0, MaxIter):
        for i in range(0, PopSize):
            
            pop[i]['velocity'] = w*pop[i]['velocity'] \
                + c1*np.random.rand(nVar)*(pop[i]['best_position'] - pop[i]['position']) \
                + c2*np.random.rand(nVar)*(gbest['position'] - pop[i]['position'])

            pop[i]['position'] += pop[i]['velocity']
            pop[i]['position'] = np.maximum(pop[i]['position'], VarMin)
            pop[i]['position'] = np.minimum(pop[i]['position'], VarMax)

            pop[i]['cost'] = CostFunction(pop[i]['position'])
            
            if pop[i]['cost'] < pop[i]['best_cost']:
                pop[i]['best_position'] = pop[i]['position'].copy()
                pop[i]['best_cost'] = pop[i]['cost']

                if pop[i]['best_cost'] < gbest['cost']:
                    gbest['position'] = pop[i]['best_position'].copy()
                    gbest['cost'] = pop[i]['best_cost']

        w *= wdamp
        print('Iteration {}: Best Cost = {}'.format(it, gbest['cost']))

    return gbest, pop

# %%
# A Sample Cost Function
def Sphere(x):
    return 400/x + 2*np.pi*(x**2)

# Define Optimization Problem
problem = {
        'CostFunction': Sphere, 
        'nVar': 10, 
        'VarMin': -5,   
        'VarMax': 5,  
    }

# Running PSO
print('Running PSO ...')
gbest, pop = PSO(problem, MaxIter = 200, PopSize = 50, c1 = 1.5, c2 = 2, w = 1, wdamp = 0.995)

# Final Result
print('Global Best:')
print(gbest)
print()
# Out:
# Running PSO ...
# Iteration 0: Best Cost = 23.851717644506113
# Iteration 1: Best Cost = 23.851717644506113
# Iteration 2: Best Cost = 21.719143087088877
# Iteration 3: Best Cost = 21.719143087088877
# Iteration 4: Best Cost = 21.719143087088877
# Iteration 5: Best Cost = 21.719143087088877
# Iteration 6: Best Cost = 13.345809598934743
# Iteration 7: Best Cost = 13.345809598934743
# Iteration 8: Best Cost = 13.345809598934743
# Iteration 9: Best Cost = 13.345809598934743
# Iteration 10: Best Cost = 13.345809598934743
# Iteration 11: Best Cost = 13.345809598934743
# Iteration 12: Best Cost = 13.345809598934743
# Iteration 13: Best Cost = 13.345809598934743
# Iteration 14: Best Cost = 12.85747022604713
# Iteration 15: Best Cost = 12.85747022604713
# Iteration 16: Best Cost = 12.85747022604713
# Iteration 17: Best Cost = 12.85747022604713
# Iteration 18: Best Cost = 12.85747022604713
# Iteration 19: Best Cost = 12.85747022604713
# Iteration 20: Best Cost = 12.85747022604713
# Iteration 21: Best Cost = 12.85747022604713
# Iteration 22: Best Cost = 12.85747022604713
# Iteration 23: Best Cost = 9.868188103464902
# Iteration 24: Best Cost = 9.868188103464902
# Iteration 25: Best Cost = 9.868188103464902
# Iteration 26: Best Cost = 9.868188103464902
# Iteration 27: Best Cost = 9.868188103464902
# Iteration 28: Best Cost = 9.868188103464902
# Iteration 29: Best Cost = 9.868188103464902
# Iteration 30: Best Cost = 9.868188103464902
# Iteration 31: Best Cost = 9.868188103464902
# Iteration 32: Best Cost = 9.868188103464902
# Iteration 33: Best Cost = 7.039655152023027
# Iteration 34: Best Cost = 7.039655152023027
# Iteration 35: Best Cost = 7.039655152023027
# Iteration 36: Best Cost = 7.039655152023027
# Iteration 37: Best Cost = 7.039655152023027
# Iteration 38: Best Cost = 7.039655152023027
# Iteration 39: Best Cost = 7.039655152023027
# Iteration 40: Best Cost = 7.039655152023027
# Iteration 41: Best Cost = 7.039655152023027
# Iteration 42: Best Cost = 7.039655152023027
# Iteration 43: Best Cost = 5.61500516382069
# Iteration 44: Best Cost = 5.61500516382069
# Iteration 45: Best Cost = 5.61500516382069
# Iteration 46: Best Cost = 5.61500516382069
# Iteration 47: Best Cost = 4.129932523547034
# Iteration 48: Best Cost = 4.129932523547034
# Iteration 49: Best Cost = 4.129932523547034
# Iteration 50: Best Cost = 4.129932523547034
# Iteration 51: Best Cost = 3.170273198137662
# Iteration 52: Best Cost = 3.170273198137662
# Iteration 53: Best Cost = 3.170273198137662
# Iteration 54: Best Cost = 2.7534070079959485
# Iteration 55: Best Cost = 2.0442223190695312
# Iteration 56: Best Cost = 2.0442223190695312
# Iteration 57: Best Cost = 2.0442223190695312
# Iteration 58: Best Cost = 2.0442223190695312
# Iteration 59: Best Cost = 2.0442223190695312
# Iteration 60: Best Cost = 2.0442223190695312
# Iteration 61: Best Cost = 2.0442223190695312
# Iteration 62: Best Cost = 2.0442223190695312
# Iteration 63: Best Cost = 2.020711342525038
# Iteration 64: Best Cost = 2.012337656718172
# Iteration 65: Best Cost = 2.012337656718172
# Iteration 66: Best Cost = 1.4008462918166775
# Iteration 67: Best Cost = 1.241216167666165
# Iteration 68: Best Cost = 1.241216167666165
# Iteration 69: Best Cost = 1.241216167666165
# Iteration 70: Best Cost = 1.238533498386036
# Iteration 71: Best Cost = 1.238533498386036
# Iteration 72: Best Cost = 1.1362935160965166
# Iteration 73: Best Cost = 1.1362935160965166
# Iteration 74: Best Cost = 1.1362935160965166
# Iteration 75: Best Cost = 1.1362935160965166
# Iteration 76: Best Cost = 0.5488900169306538
# Iteration 77: Best Cost = 0.5488900169306538
# Iteration 78: Best Cost = 0.5488900169306538
# Iteration 79: Best Cost = 0.5001060900057407
# Iteration 80: Best Cost = 0.5001060900057407
# Iteration 81: Best Cost = 0.5001060900057407
# Iteration 82: Best Cost = 0.5001060900057407
# Iteration 83: Best Cost = 0.4667557370320868
# Iteration 84: Best Cost = 0.2307229650910205
# Iteration 85: Best Cost = 0.2307229650910205
# Iteration 86: Best Cost = 0.2307229650910205
# Iteration 87: Best Cost = 0.2307229650910205
# Iteration 88: Best Cost = 0.2307229650910205
# Iteration 89: Best Cost = 0.2307229650910205
# Iteration 90: Best Cost = 0.22974767303564028
# Iteration 91: Best Cost = 0.22974767303564028
# Iteration 92: Best Cost = 0.22974767303564028
# Iteration 93: Best Cost = 0.22974767303564028
# Iteration 94: Best Cost = 0.22974767303564028
# Iteration 95: Best Cost = 0.22974767303564028
# Iteration 96: Best Cost = 0.16121251931829697
# Iteration 97: Best Cost = 0.16121251931829697
# Iteration 98: Best Cost = 0.11104662694768318
# Iteration 99: Best Cost = 0.08249649347319328
# Iteration 100: Best Cost = 0.08249649347319328
# Iteration 101: Best Cost = 0.08249649347319328
# Iteration 102: Best Cost = 0.06789684657191285
# Iteration 103: Best Cost = 0.02784274671965005
# Iteration 104: Best Cost = 0.027316462112617346
# Iteration 105: Best Cost = 0.016058717600771204
# Iteration 106: Best Cost = 0.016058717600771204
# Iteration 107: Best Cost = 0.016058717600771204
# Iteration 108: Best Cost = 0.016058717600771204
# Iteration 109: Best Cost = 0.016058717600771204
# Iteration 110: Best Cost = 0.016058717600771204
# Iteration 111: Best Cost = 0.015426274540923383
# Iteration 112: Best Cost = 0.015426274540923383
# Iteration 113: Best Cost = 0.015108639939936087
# Iteration 114: Best Cost = 0.015108639939936087
# Iteration 115: Best Cost = 0.012346033859827407
# Iteration 116: Best Cost = 0.008318901439337672
# Iteration 117: Best Cost = 0.004366496220216374
# Iteration 118: Best Cost = 0.004366496220216374
# Iteration 119: Best Cost = 0.004366496220216374
# Iteration 120: Best Cost = 0.004366496220216374
# Iteration 121: Best Cost = 0.004366496220216374
# Iteration 122: Best Cost = 0.0026228654589636625
# Iteration 123: Best Cost = 0.002578041466596465
# Iteration 124: Best Cost = 0.002463341578421226
# Iteration 125: Best Cost = 0.000924735439055753
# Iteration 126: Best Cost = 0.0009092683094715831
# Iteration 127: Best Cost = 0.000906782920912133
# Iteration 128: Best Cost = 0.000906782920912133
# Iteration 129: Best Cost = 0.000906782920912133
# Iteration 130: Best Cost = 0.00034447333767061974
# Iteration 131: Best Cost = 0.00034447333767061974
# Iteration 132: Best Cost = 0.0003196526854120752
# Iteration 133: Best Cost = 0.00031004613404372227
# Iteration 134: Best Cost = 0.00026625487358186966
# Iteration 135: Best Cost = 0.0001021112106664487
# Iteration 136: Best Cost = 7.005568918700172e-05
# Iteration 137: Best Cost = 7.005568918700172e-05
# Iteration 138: Best Cost = 7.005568918700172e-05
# Iteration 139: Best Cost = 6.145054932442101e-05
# Iteration 140: Best Cost = 5.8881713669403665e-05
# Iteration 141: Best Cost = 2.0597523996479914e-05
# Iteration 142: Best Cost = 2.0597523996479914e-05
# Iteration 143: Best Cost = 1.6628276429589977e-05
# Iteration 144: Best Cost = 1.5613958147219908e-05
# Iteration 145: Best Cost = 1.377159407854535e-05
# Iteration 146: Best Cost = 1.2773150976060634e-05
# Iteration 147: Best Cost = 1.2773150976060634e-05
# Iteration 148: Best Cost = 1.0870506071184468e-05
# Iteration 149: Best Cost = 4.4034304125771545e-06
# Iteration 150: Best Cost = 4.4034304125771545e-06
# Iteration 151: Best Cost = 2.9438804692989587e-06
# Iteration 152: Best Cost = 2.9438804692989587e-06
# Iteration 153: Best Cost = 2.8937839224434836e-06
# Iteration 154: Best Cost = 2.8717692572406475e-06
# Iteration 155: Best Cost = 9.636832269160895e-07
# Iteration 156: Best Cost = 9.636832269160895e-07
# Iteration 157: Best Cost = 8.715160577252007e-07
# Iteration 158: Best Cost = 8.715160577252007e-07
# Iteration 159: Best Cost = 4.147416822160697e-07
# Iteration 160: Best Cost = 4.147416822160697e-07
# Iteration 161: Best Cost = 3.404780195525949e-07
# Iteration 162: Best Cost = 3.0603087977106845e-07
# Iteration 163: Best Cost = 1.476449000767397e-07
# Iteration 164: Best Cost = 1.476449000767397e-07
# Iteration 165: Best Cost = 8.184967664192475e-08
# Iteration 166: Best Cost = 8.184967664192475e-08
# Iteration 167: Best Cost = 8.184967664192475e-08
# Iteration 168: Best Cost = 8.184967664192475e-08
# Iteration 169: Best Cost = 4.764655417552781e-08
# Iteration 170: Best Cost = 3.090520295293617e-08
# Iteration 171: Best Cost = 3.090520295293617e-08
# Iteration 172: Best Cost = 9.334367976579427e-09
# Iteration 173: Best Cost = 7.854541799621642e-09
# Iteration 174: Best Cost = 7.854541799621642e-09
# Iteration 175: Best Cost = 5.767208784935666e-09
# Iteration 176: Best Cost = 4.5411961622196865e-09
# Iteration 177: Best Cost = 4.5411961622196865e-09
# Iteration 178: Best Cost = 4.316142931552437e-09
# Iteration 179: Best Cost = 2.307866551393449e-09
# Iteration 180: Best Cost = 1.3304347222881355e-09
# Iteration 181: Best Cost = 9.586632873314432e-10
# Iteration 182: Best Cost = 9.586632873314432e-10
# Iteration 183: Best Cost = 5.662404021992583e-10
# Iteration 184: Best Cost = 4.783826758194606e-10
# Iteration 185: Best Cost = 4.2887003936774394e-10
# Iteration 186: Best Cost = 4.2887003936774394e-10
# Iteration 187: Best Cost = 1.8777331336049168e-10
# Iteration 188: Best Cost = 1.842763586626421e-10
# Iteration 189: Best Cost = 1.1428779807189431e-10
# Iteration 190: Best Cost = 9.161937436041525e-11
# Iteration 191: Best Cost = 9.06799395158732e-11
# Iteration 192: Best Cost = 5.274224488211758e-11
# Iteration 193: Best Cost = 2.993407720254959e-11
# Iteration 194: Best Cost = 2.993407720254959e-11
# Iteration 195: Best Cost = 2.3845265249926887e-11
# Iteration 196: Best Cost = 1.5163815485485062e-11
# Iteration 197: Best Cost = 1.5163815485485062e-11
# Iteration 198: Best Cost = 8.879987016791736e-12
# Iteration 199: Best Cost = 7.796747154482396e-12
# Global Best:
# {'position': array([-1.79792975e-06,  3.03769137e-07,  7.03583245e-07,  5.07991015e-07,
#         1.03962436e-08, -9.58358019e-08,  9.93139388e-09,  6.61161950e-07,
#        -1.79341559e-06, -2.36579780e-07]), 'cost': 7.796747154482396e-12}
